# %%
#importing modules
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import requests
from datetime import datetime, date, timedelta
import subprocess
import time
import sys

# %%
#initializes log, only appends print statements to log file, uncomment if you want the functionality
#log_file = open("message.log","w")
#sys.stdout = log_file

# %%
#User specified inputs
age_filter = 18 #possible options = 18, 45, None
vac_name = "COVAXIN" #possible options = "COVAXIN", "COVISHIELD", None
fee_filter = None #possible options = "Free" "Paid" None
min_slots = None #min available slots must be equal to or greater than min_slots for alarm to be raised
district_id = [141,145,140,146,147,143,148,149,144,150,142] #can specify multiple district ids get district id from cowin platform(see readme for more details)
open_browser = r"C:\Program Files (x86)\Google\Chrome\Application\chrome.exe" #if you want to automatically open cowin sign in page if conditions are met, specify the browser path here. Else choose None
hrs = 2 #number of hrs you want the program to run, cannot be None or blank, must be an whole number
mins = 0 #number of mins you want the program to run, cannot be None or blank, must be an whole number

# %%
#prints user input for log reference
print('age_filter is: ' + str(age_filter))
print('vac_name is: ' + str(vac_name))
print('fee_filter is: ' + str(fee_filter))
print('min_slots is: ' + str(min_slots))
print('district_id is: ' + str(district_id))
print('open_browser is: ' + str(open_browser))
print('hrs is: ' + str(hrs))
print('mins is: ' + str(mins) + '\n')
# Out:
# age_filter is: 18
# vac_name is: COVAXIN
# fee_filter is: None
# min_slots is: None
# district_id is: [141, 145, 140, 146, 147, 143, 148, 149, 144, 150, 142]
# open_browser is: C:\Program Files (x86)\Google\Chrome\Application\chrome.exe
# hrs is: 2
# mins is: 0

# %%
#clock code - keeps time of the script run
x = hrs
y = mins
x = int(x)
y = int(y)

#prints start time in HH:MM:SS format
start_time = datetime.now()
start = start_time.strftime('%H:%M:%S')
print("The start time is " + start)

#prints end time in HH:MM:SS format
stop_after = timedelta(hours = x, minutes = y)
end_time = start_time + stop_after
end = end_time.strftime('%H:%M:%S')
print("The end time is " + end)

#calculates time_left_script, this variable will be updated to estimate how much more time the script must run
time_left_script = (y*60) + (x*60*60)
# Out:
# The start time is 19:47:40
# The end time is 21:47:40

# %%
#system input - date
today_date = datetime.today().strftime('%d-%m-%Y')
print('Fetching data for ' +str(today_date) + ' and the next 7 days'+'\n')
# Out:
# Fetching data for 19-05-2021 and the next 7 days

# %%
#Main Programme

#Max requests to the server in a 5 min time frame is restricted to 100, secs_until_newwin indicates seconds left until new window of 5 mins starts
#requests_left indicates available requests in seconds until new window
#The optimization for 100 requests assumes the user will be running the program for more than 5 minutes, atleast. 
#If runtime less than 5 mins, the program will run only a few batches when more could have been run to complete the 100 request limit
secs_until_newwin = (5*60)
requests_left = 100

iteration_number = 1 #iteration means the number of times requests are sent to the server

  
while time_left_script>0:
    start_time_iteration = time.time()
    
    try:
        #1.Loops through district_id, parses request result for each element and concatenates in dataframe 
        #2.Applies filters and generates final dataframe
        print('iteration number: '+str(iteration_number))
        
        df = pd.DataFrame()
        for i in district_id:
            iteration_number+=1
            URL = r"https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/findByDistrict?district_id={}&date={}".format(i,today_date)
            #The user-agent line helps identify the browser and operating system of the user(who generates the request)
            pi = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36"}
            request_response = requests.get(URL, headers = pi)
            dict_req_resp = request_response.json()
            
            for key,value in (dict_req_resp.items()):
                for element in range(len(value)):
                    for i,j in value[element].items():
                        df_iteration = pd.DataFrame.from_dict(value[element])
                        df = pd.concat([df,df_iteration])
        
        if df.empty:
            print('No records found for this iteration')
            
        elif len(df)==0:
            print('No records found for this iteration')
    
        else:
            #Applying filters
            df_fin = df[(df['available_capacity']>=min_slots)]
            ##vaccine filter
            if vac_name is not None:
                df_fin = df_fin[df_fin['vaccine']==vac_name]
                
            #age limit filter
            if age_filter is not None:
                df_fin = df_fin[df_fin['min_age_limit']==age_filter]
                
            #fee filter
            if fee_filter is not None:
                df_fin = df_fin[df_fin['fee_type']==fee_filter]
            
            df_fin = df_fin.reset_index()
            df_fin = df_fin.drop(columns={'index'})
            #prints to csv if filtered output has slots
            if len(df_fin)>0:
                df_fin.to_csv(r"slots.csv", index = False)
            
            #opens alarm, opens slots.csv and launches cowin signin webpage
            if len(df_fin)>0:
                print('Search successful. Open slots.csv for info on the available slots.')
                subprocess.Popen(['start','success_song.mp3'], shell = True)
                if open_browser is not None:
                    subprocess.Popen([open_browser, r"https://selfregistration.cowin.gov.in/"])
                subprocess.Popen('slots.csv', shell = True)
                break
                    
    except:
        print('Either you have hit the 100 ceiling for requests in 5 min window or something else is wrong in the main program!')
    
    end_time_iteration = time.time()
    #sleep_time calculates how long the program sleeps so that 100 requests can be made in a 5 minute window
    sleep_time = ((secs_until_newwin*len(district_id))/requests_left)-(end_time_iteration-start_time_iteration)
    if sleep_time<0:
        sleep_time = 0
    print('time_taken to run the batch: ' +str(end_time_iteration-start_time_iteration) + ' seconds') #here, batch means the entire group of district id.
    secs_until_newwin = secs_until_newwin - sleep_time
    requests_left = requests_left - len(district_id)
    print('secs_until_newwin: ' + str(secs_until_newwin) + ' seconds')
    print('requests_left: ' + str(requests_left))
    time_left_script = time_left_script-(end_time_iteration-start_time_iteration)-sleep_time
    print('sleep time: '+str(min(sleep_time,secs_until_newwin))+ ' seconds' + '\n')
    
    if requests_left < len(district_id):
        sleep_time = secs_until_newwin
    time.sleep(min(secs_until_newwin,sleep_time))
    
    
    if sleep_time>=secs_until_newwin:
        secs_until_newwin = (5*60)
        requests_left = 100
               
print('Script time elapsed')
# Out:
# iteration number: 1
# time_taken to run the batch: 16.928744792938232 seconds
# secs_until_newwin: 283.92874479293823 seconds
# requests_left: 89
# sleep time: 16.071255207061768 seconds
#
# iteration number: 12
# time_taken to run the batch: 17.456725120544434 seconds
# secs_until_newwin: 266.29315314132174 seconds
# requests_left: 78
# sleep time: 17.635591651616473 seconds
#
# iteration number: 23
# time_taken to run the batch: 15.682857036590576 seconds
# secs_until_newwin: 244.42184755541822 seconds
# requests_left: 67
# sleep time: 21.871305585903514 seconds
#
# iteration number: 34
# time_taken to run the batch: 15.802334070205688 seconds
# secs_until_newwin: 220.09522157921197 seconds
# requests_left: 56
# sleep time: 24.32662597620626 seconds
#
# iteration number: 45
# time_taken to run the batch: 16.41355586051941 seconds
# secs_until_newwin: 193.2757874866719 seconds
# requests_left: 45
# sleep time: 26.819434092540078 seconds
#
# iteration number: 56
# time_taken to run the batch: 16.5879807472229 seconds
# secs_until_newwin: 162.61857573715278 seconds
# requests_left: 34
# sleep time: 30.65721174951912 seconds
#
# iteration number: 67
# time_taken to run the batch: 15.878059387207031 seconds
# secs_until_newwin: 125.88474297410451 seconds
# requests_left: 23
# sleep time: 36.73383276304828 seconds
#
# iteration number: 78
# time_taken to run the batch: 16.004801750183105 seconds
# secs_until_newwin: 81.6837980844985 seconds
# requests_left: 12
# sleep time: 44.200944889606006 seconds
#
# iteration number: 89
# time_taken to run the batch: 15.970515489578247 seconds
# secs_until_newwin: 22.77749866328645 seconds
# requests_left: 1
# sleep time: 22.77749866328645 seconds
#
# iteration number: 100
# time_taken to run the batch: 15.691409587860107 seconds
# secs_until_newwin: 282.6914095878601 seconds
# requests_left: 89
# sleep time: 17.308590412139893 seconds
#
# iteration number: 111
# time_taken to run the batch: 16.0584876537323 seconds
# secs_until_newwin: 263.81050953972203 seconds
# requests_left: 78
# sleep time: 18.880900048138052 seconds
#
# iteration number: 122
# time_taken to run the batch: 16.166595935821533 seconds
# secs_until_newwin: 242.7730592584033 seconds
# requests_left: 67
# sleep time: 21.037450281318748 seconds
#
# iteration number: 133
# time_taken to run the batch: 17.699878692626953 seconds
# secs_until_newwin: 220.6146744906954 seconds
# requests_left: 56
# sleep time: 22.158384767707915 seconds
#
# iteration number: 144
# time_taken to run the batch: 15.824331760406494 seconds
# secs_until_newwin: 193.10398090471529 seconds
# requests_left: 45
# sleep time: 27.5106935859801 seconds
#
# iteration number: 155
# time_taken to run the batch: 21.357812881469727 seconds
# secs_until_newwin: 167.25859845392128 seconds
# requests_left: 34
# sleep time: 25.845382450794013 seconds
#
# iteration number: 166
# time_taken to run the batch: 16.22571325302124 seconds
# secs_until_newwin: 129.37123573655623 seconds
# requests_left: 23
# sleep time: 37.88736271736506 seconds
#
# iteration number: 177
# time_taken to run the batch: 16.212968587875366 seconds
# secs_until_newwin: 83.71100462433948 seconds
# requests_left: 12
# sleep time: 45.66023111221675 seconds
#
# iteration number: 188
# time_taken to run the batch: 16.161949634552002 seconds
# secs_until_newwin: 23.137866686580296 seconds
# requests_left: 1
# sleep time: 23.137866686580296 seconds
#
# iteration number: 199
# time_taken to run the batch: 19.31708312034607 seconds
# secs_until_newwin: 286.31708312034607 seconds
# requests_left: 89
# sleep time: 13.68291687965393 seconds
#
# iteration number: 210
# time_taken to run the batch: 16.276031732559204 seconds
# secs_until_newwin: 267.2056101975816 seconds
# requests_left: 78
# sleep time: 19.11147292276447 seconds
#
# iteration number: 221
# time_taken to run the batch: 16.443195819854736 seconds
# secs_until_newwin: 245.96596355367484 seconds
# requests_left: 67
# sleep time: 21.239646643906774 seconds
#
# iteration number: 232
# time_taken to run the batch: 16.122824907302856 seconds
# secs_until_newwin: 221.7063168327624 seconds
# requests_left: 56
# sleep time: 24.259646720912414 seconds
#
# iteration number: 243
# time_taken to run the batch: 16.118979454040527 seconds
# secs_until_newwin: 194.2758411946532 seconds
# requests_left: 45
# sleep time: 27.43047563810923 seconds
#
# iteration number: 254
# time_taken to run the batch: 16.108110904693604 seconds
# secs_until_newwin: 162.8943020295427 seconds
# requests_left: 34
# sleep time: 31.38153916511051 seconds
#
# iteration number: 265
# time_taken to run the batch: 15.671446800231934 seconds
# secs_until_newwin: 125.86465111433435 seconds
# requests_left: 23
# sleep time: 37.02965091520835 seconds
#
# iteration number: 276
# time_taken to run the batch: 15.58850359916687 seconds
# secs_until_newwin: 81.25701722403696 seconds
# requests_left: 12
# sleep time: 44.607633890297386 seconds
#
# iteration number: 287
# time_taken to run the batch: 15.585823774337769 seconds
# secs_until_newwin: 22.35724187634085 seconds
# requests_left: 1
# sleep time: 22.35724187634085 seconds
#
# iteration number: 298
# time_taken to run the batch: 15.801638126373291 seconds
# secs_until_newwin: 282.8016381263733 seconds
# requests_left: 89
# sleep time: 17.19836187362671 seconds
#
# iteration number: 309
# time_taken to run the batch: 15.487342119216919 seconds
# secs_until_newwin: 263.3359687917688 seconds
# requests_left: 78
# sleep time: 19.4656693346045 seconds
#
# iteration number: 320
# time_taken to run the batch: 15.872921466827393 seconds
# secs_until_newwin: 242.07176645462877 seconds
# requests_left: 67
# sleep time: 21.26420233714 seconds
#
# iteration number: 331
# time_taken to run the batch: 15.910189151763916 seconds
# secs_until_newwin: 218.2388297705581 seconds
# requests_left: 56
# sleep time: 23.83293668407066 seconds
#
# iteration number: 342
# time_taken to run the batch: 15.815496683120728 seconds
# secs_until_newwin: 191.18598489160493 seconds
# requests_left: 45
# sleep time: 27.052844878953188 seconds
#
# iteration number: 353
# time_taken to run the batch: 16.382352828979492 seconds
# secs_until_newwin: 160.8339858581921 seconds
# requests_left: 34
# sleep time: 30.351999033412824 seconds
#
# iteration number: 364
# time_taken to run the batch: 16.110938549041748 seconds
# secs_until_newwin: 124.91039957075994 seconds
# requests_left: 23
# sleep time: 35.92358628743217 seconds
#
# iteration number: 375
# time_taken to run the batch: 16.061354398727417 seconds
# secs_until_newwin: 81.23199765303696 seconds
# requests_left: 12
# sleep time: 43.67840191772298 seconds
#
# iteration number: 386
# time_taken to run the batch: 17.088902711868286 seconds
# secs_until_newwin: 23.858235849621366 seconds
# requests_left: 1
# sleep time: 23.858235849621366 seconds
#
# iteration number: 397
# time_taken to run the batch: 16.59310030937195 seconds
# secs_until_newwin: 283.59310030937195 seconds
# requests_left: 89
# sleep time: 16.40689969062805 seconds
#
# iteration number: 408
# time_taken to run the batch: 15.036962747573853 seconds
# secs_until_newwin: 263.5792304344392 seconds
# requests_left: 78
# sleep time: 20.013869874932794 seconds
#
# iteration number: 419
# time_taken to run the batch: 15.954100131988525 seconds
# secs_until_newwin: 242.36190063336576 seconds
# requests_left: 67
# sleep time: 21.21732980107341 seconds
#
# iteration number: 430
# time_taken to run the batch: 15.916413068771362 seconds
# secs_until_newwin: 218.48755389665916 seconds
# requests_left: 56
# sleep time: 23.8743467367066 seconds
#
# iteration number: 441
# time_taken to run the batch: 15.631162643432617 seconds
# secs_until_newwin: 191.201518453248 seconds
# requests_left: 45
# sleep time: 27.28603544341115 seconds
#
# iteration number: 452
# time_taken to run the batch: 15.42992639541626 seconds
# secs_until_newwin: 159.89329589342586 seconds
# requests_left: 34
# sleep time: 31.30822255982215 seconds
#
# iteration number: 463
# time_taken to run the batch: 15.692708969116211 seconds
# secs_until_newwin: 123.85582089702194 seconds
# requests_left: 23
# sleep time: 36.037474996403915 seconds
#
# iteration number: 474
# time_taken to run the batch: 15.463364124298096 seconds
# secs_until_newwin: 80.0837924183965 seconds
# requests_left: 12
# sleep time: 43.772028478625444 seconds
#
# iteration number: 485
# time_taken to run the batch: 19.70078682899475 seconds
# secs_until_newwin: 26.374436197194456 seconds
# requests_left: 1
# sleep time: 26.374436197194456 seconds
#
# iteration number: 496
# time_taken to run the batch: 18.165876150131226 seconds
# secs_until_newwin: 285.1658761501312 seconds
# requests_left: 89
# sleep time: 14.834123849868774 seconds
#
# iteration number: 507
# time_taken to run the batch: 15.254487037658691 seconds
# secs_until_newwin: 265.1751425400209 seconds
# requests_left: 78
# sleep time: 19.99073361011034 seconds
#
# iteration number: 518
# time_taken to run the batch: 16.056726217269897 seconds
# secs_until_newwin: 243.8353742965186 seconds
# requests_left: 67
# sleep time: 21.339768243502277 seconds
#
# iteration number: 529
# time_taken to run the batch: 15.727551698684692 seconds
# secs_until_newwin: 219.53025260323756 seconds
# requests_left: 56
# sleep time: 24.305121693281052 seconds
#
# iteration number: 540
# time_taken to run the batch: 15.29858136177063 seconds
# secs_until_newwin: 191.7068200608008 seconds
# requests_left: 45
# sleep time: 27.82343254243675 seconds
#
# iteration number: 551
# time_taken to run the batch: 15.866525888442993 seconds
# secs_until_newwin: 160.71167882327026 seconds
# requests_left: 34
# sleep time: 30.995141237530532 seconds
#
# iteration number: 562
# time_taken to run the batch: 16.216082334518433 seconds
# secs_until_newwin: 124.93280624437773 seconds
# requests_left: 23
# sleep time: 35.77887257889253 seconds
#
# iteration number: 573
# time_taken to run the batch: 18.185829401016235 seconds
# secs_until_newwin: 83.36816309373506 seconds
# requests_left: 12
# sleep time: 41.564643150642674 seconds
#
# iteration number: 584
# time_taken to run the batch: 16.59846019744873 seconds
# secs_until_newwin: 23.545807121926657 seconds
# requests_left: 1
# sleep time: 23.545807121926657 seconds
#
# iteration number: 595
# time_taken to run the batch: 16.81512951850891 seconds
# secs_until_newwin: 283.8151295185089 seconds
# requests_left: 89
# sleep time: 16.18487048149109 seconds
#
# iteration number: 606
# time_taken to run the batch: 16.782506942749023 seconds
# secs_until_newwin: 265.51936202638603 seconds
# requests_left: 78
# sleep time: 18.295767492122863 seconds
#
# iteration number: 617
# time_taken to run the batch: 15.969155550003052 seconds
# secs_until_newwin: 244.04347934189875 seconds
# requests_left: 67
# sleep time: 21.47588268448728 seconds
#
# iteration number: 628
# time_taken to run the batch: 26.459044218063354 seconds
# secs_until_newwin: 230.43568366800858 seconds
# requests_left: 56
# sleep time: 13.607795673890173 seconds
#
# iteration number: 639
# time_taken to run the batch: 20.415431022644043 seconds
# secs_until_newwin: 205.5869625415795 seconds
# requests_left: 45
# sleep time: 24.848721126429076 seconds
#
# iteration number: 650
# time_taken to run the batch: 16.288621425628662 seconds
# secs_until_newwin: 171.62099312371095 seconds
# requests_left: 34
# sleep time: 33.96596941786856 seconds
#
# iteration number: 661
# time_taken to run the batch: 16.50479030609131 seconds
# secs_until_newwin: 132.6013444780134 seconds
# requests_left: 23
# sleep time: 39.01964864569753 seconds
#
# iteration number: 672
# time_taken to run the batch: 18.912585258483887 seconds
# secs_until_newwin: 88.09589542092566 seconds
# requests_left: 12
# sleep time: 44.505449057087745 seconds
#
# iteration number: 683
# time_taken to run the batch: 16.098251581192017 seconds
# secs_until_newwin: 23.439576199602485 seconds
# requests_left: 1
# sleep time: 23.439576199602485 seconds
#
# iteration number: 694
# time_taken to run the batch: 20.4389705657959 seconds
# secs_until_newwin: 287.4389705657959 seconds
# requests_left: 89
# sleep time: 12.561029434204102 seconds
#
# iteration number: 705
# time_taken to run the batch: 19.795891523361206 seconds
# secs_until_newwin: 271.7086971877666 seconds
# requests_left: 78
# sleep time: 15.730273378029295 seconds
#
# iteration number: 716
# time_taken to run the batch: 18.320776224136353 seconds
# secs_until_newwin: 251.71158021875635 seconds
# requests_left: 67
# sleep time: 19.997116969010214 seconds
#
# iteration number: 727
# time_taken to run the batch: 21.643535614013672 seconds
# secs_until_newwin: 232.02933400581003 seconds
# requests_left: 56
# sleep time: 19.682246212946325 seconds
#
# iteration number: 738
# time_taken to run the batch: 19.009899854660034 seconds
# secs_until_newwin: 205.46204325218594 seconds
# requests_left: 45
# sleep time: 26.56729075362408 seconds
#
# iteration number: 749
# time_taken to run the batch: 17.74998450279236 seconds
# secs_until_newwin: 172.98797273777728 seconds
# requests_left: 34
# sleep time: 32.474070514408645 seconds
#
# iteration number: 760
# time_taken to run the batch: 22.95862627029419 seconds
# secs_until_newwin: 139.9799019458494 seconds
# requests_left: 23
# sleep time: 33.00807079192788 seconds
#
# iteration number: 771
# time_taken to run the batch: 21.465051412582397 seconds
# secs_until_newwin: 94.498043732156 seconds
# requests_left: 12
# sleep time: 45.4818582136934 seconds
#
# iteration number: 782
# time_taken to run the batch: 16.75232481956482 seconds
# secs_until_newwin: 24.627161797244497 seconds
# requests_left: 1
# sleep time: 24.627161797244497 seconds
#
# iteration number: 793
# time_taken to run the batch: 17.239787817001343 seconds
# secs_until_newwin: 284.23978781700134 seconds
# requests_left: 89
# sleep time: 15.760212182998657 seconds
#
# iteration number: 804
# time_taken to run the batch: 18.458844661712646 seconds
# secs_until_newwin: 267.5678721867251 seconds
# requests_left: 78
# sleep time: 16.67191563027628 seconds
#
# iteration number: 815
# time_taken to run the batch: 18.50057029724121 seconds
# secs_until_newwin: 248.3345117909666 seconds
# requests_left: 67
# sleep time: 19.23336039575848 seconds
#
# iteration number: 826
# time_taken to run the batch: 16.75830864906311 seconds
# secs_until_newwin: 224.32148268330383 seconds
# requests_left: 56
# sleep time: 24.013029107662753 seconds
#
# iteration number: 837
# time_taken to run the batch: 16.422877073287964 seconds
# secs_until_newwin: 196.6812113723714 seconds
# requests_left: 45
# sleep time: 27.640271310932427 seconds
#
# iteration number: 848
# time_taken to run the batch: 18.26626944541931 seconds
# secs_until_newwin: 166.86985137121104 seconds
# requests_left: 34
# sleep time: 29.81136000116036 seconds
#
# iteration number: 859
# time_taken to run the batch: 14.363481283187866 seconds
# secs_until_newwin: 127.2460277990071 seconds
# requests_left: 23
# sleep time: 39.62382357220394 seconds
#
# iteration number: 870
# time_taken to run the batch: 18.318141222000122 seconds
# secs_until_newwin: 84.70737311713427 seconds
# requests_left: 12
# sleep time: 42.538654681872835 seconds
#
# iteration number: 881
# time_taken to run the batch: 16.372881650924683 seconds
# secs_until_newwin: 23.431829410685864 seconds
# requests_left: 1
# sleep time: 23.431829410685864 seconds
#
# iteration number: 892
# time_taken to run the batch: 15.404223918914795 seconds
# secs_until_newwin: 282.4042239189148 seconds
# requests_left: 89
# sleep time: 17.595776081085205 seconds
#
# iteration number: 903
# time_taken to run the batch: 16.88609004020691 seconds
# secs_until_newwin: 264.3864211152109 seconds
# requests_left: 78
# sleep time: 18.01780280370391 seconds
#
# iteration number: 914
# time_taken to run the batch: 19.271199941635132 seconds
# secs_until_newwin: 246.37235654059833 seconds
# requests_left: 67
# sleep time: 18.01406457461256 seconds
#
# iteration number: 925
# time_taken to run the batch: 15.363706588745117 seconds
# secs_until_newwin: 221.2868702644691 seconds
# requests_left: 56
# sleep time: 25.085486276129238 seconds
#
# iteration number: 936
# time_taken to run the batch: 16.318256855010986 seconds
# secs_until_newwin: 194.1380633175308 seconds
# requests_left: 45
# sleep time: 27.1488069469383 seconds
#
# iteration number: 947
# time_taken to run the batch: 15.957796096801758 seconds
# secs_until_newwin: 162.63988838115836 seconds
# requests_left: 34
# sleep time: 31.498174936372443 seconds
#
# iteration number: 958
# time_taken to run the batch: 18.547462940216064 seconds
# secs_until_newwin: 128.56856390394086 seconds
# requests_left: 23
# sleep time: 34.071324477217516 seconds
#
# iteration number: 969
# time_taken to run the batch: 15.193028450012207 seconds
# secs_until_newwin: 82.2722791825031 seconds
# requests_left: 12
# sleep time: 46.296284721437765 seconds
#
# iteration number: 980
# time_taken to run the batch: 15.01075553894043 seconds
# secs_until_newwin: 21.86677880414902 seconds
# requests_left: 1
# sleep time: 21.86677880414902 seconds
#
# iteration number: 991
# time_taken to run the batch: 14.311935424804688 seconds
# secs_until_newwin: 281.3119354248047 seconds
# requests_left: 89
# sleep time: 18.688064575195312 seconds
#
# iteration number: 1002
# time_taken to run the batch: 15.123303890228271 seconds
# secs_until_newwin: 261.6663484198324 seconds
# requests_left: 78
# sleep time: 19.645587004972306 seconds
#
# iteration number: 1013
# time_taken to run the batch: 14.072604894638062 seconds
# secs_until_newwin: 238.83728879372487 seconds
# requests_left: 67
# sleep time: 22.82905962610753 seconds
#
# iteration number: 1024
# time_taken to run the batch: 14.972238302230835 seconds
# secs_until_newwin: 214.59743490594116 seconds
# requests_left: 56
# sleep time: 24.239853887783696 seconds
#
# iteration number: 1035
# time_taken to run the batch: 14.891614198684692 seconds
# secs_until_newwin: 187.33598153381598 seconds
# requests_left: 45
# sleep time: 27.261453372125175 seconds
#
# iteration number: 1046
# time_taken to run the batch: 14.33638858795166 seconds
# secs_until_newwin: 155.8791301912793 seconds
# requests_left: 34
# sleep time: 31.456851342536687 seconds
#
# iteration number: 1057
# time_taken to run the batch: 14.113065958023071 seconds
# secs_until_newwin: 119.56071285212377 seconds
# requests_left: 23
# sleep time: 36.31841733915552 seconds
#
# iteration number: 1068
# time_taken to run the batch: 13.587965726852417 seconds
# secs_until_newwin: 75.96746808448222 seconds
# requests_left: 12
# sleep time: 43.59324476764156 seconds
#
# iteration number: 1079
# time_taken to run the batch: 12.844367980957031 seconds
# secs_until_newwin: 19.174990321330554 seconds
# requests_left: 1
# sleep time: 19.174990321330554 seconds
#
# iteration number: 1090
# time_taken to run the batch: 13.281957626342773 seconds
# secs_until_newwin: 280.2819576263428 seconds
# requests_left: 89
# sleep time: 19.718042373657227 seconds
#
# iteration number: 1101
# time_taken to run the batch: 16.65739917755127 seconds
# secs_until_newwin: 262.29776653546963 seconds
# requests_left: 78
# sleep time: 17.984191090873118 seconds
#
# iteration number: 1112
# time_taken to run the batch: 13.300822734832764 seconds
# secs_until_newwin: 238.60787860504385 seconds
# requests_left: 67
# sleep time: 23.689887930425776 seconds
#
# iteration number: 1123
# time_taken to run the batch: 13.721549034118652 seconds
# secs_until_newwin: 213.15499980848367 seconds
# requests_left: 56
# sleep time: 25.452878796560185 seconds
#
# iteration number: 1134
# time_taken to run the batch: 13.843848466873169 seconds
# secs_until_newwin: 185.12911617011898 seconds
# requests_left: 45
# sleep time: 28.025883638364697 seconds
#
# iteration number: 1145
# time_taken to run the batch: 12.656578063964844 seconds
# secs_until_newwin: 152.53191028138806 seconds
# requests_left: 34
# sleep time: 32.597205888730905 seconds
#
# iteration number: 1156
# time_taken to run the batch: 12.067472696304321 seconds
# secs_until_newwin: 115.25082376900801 seconds
# requests_left: 23
# sleep time: 37.28108651238005 seconds
#
# iteration number: 1167
# time_taken to run the batch: 11.869742631912231 seconds
# secs_until_newwin: 72.00060720704684 seconds
# requests_left: 12
# sleep time: 43.25021656196117 seconds
#
# iteration number: 1178
# time_taken to run the batch: 11.987061023712158 seconds
# secs_until_newwin: 17.987111624299402 seconds
# requests_left: 1
# sleep time: 17.987111624299402 seconds
#
# iteration number: 1189
# time_taken to run the batch: 12.578308582305908 seconds
# secs_until_newwin: 279.5783085823059 seconds
# requests_left: 89
# sleep time: 20.421691417694092 seconds
#
# iteration number: 1200
# time_taken to run the batch: 12.207604885101318 seconds
# secs_until_newwin: 257.2312910583582 seconds
# requests_left: 78
# sleep time: 22.347017523947727 seconds
#
# iteration number: 1211
# time_taken to run the batch: 4343.379064798355 seconds
# secs_until_newwin: 257.2312910583582 seconds
# requests_left: 67
# sleep time: 0 seconds
#
# Script time elapsed

# %%
#closes log, uncomment if you want to use the functionality
#sys.stdout = old_stdout
#log_file.close()
